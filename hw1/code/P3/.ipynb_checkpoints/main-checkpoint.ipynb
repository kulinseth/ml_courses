# %%
# %matplotlib inline
import numpy as np
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pylab as pl

import pdb
import random
import pylab as pl

# X is an array of N data points (one dimensional for now), that is, NX1
# Y is a Nx1 column vector of data values

def getData(name):
    data = pl.loadtxt(name)
    # Returns column matrices
    X = data[0:1]
    Y = data[1:2]
    return X[0], Y[0]

def regressAData():
    return getData('regressA_train.txt')

def regressBData():
    return getData('regressB_train.txt')

def validateData():
    return getData('regress_validate.txt')

X_A, Y_A = regressAData()
X_B, Y_B = regressBData()

def polynomial_basis(x, M):
    poly = np.arange(M+1)
    X = np.power(np.array([x]).T, poly)
    return X

# These weights are calculated using the closed form
def weights(X, Y, M, lambd):
    theta = np.dot(np.linalg.inv(lambd*np.identity(M+1) + (np.dot(X.T, X))), np.dot(X.T, Y))
    return theta
    
def predict(x, Y, M, lambd=0.0):
    X = polynomial_basis(x, M)
    theta = weights(X, Y, M, lambd)
    Y_hat = np.dot(X, theta)
    return Y_hat

# Use Regress A as Training set and B as Test data set
M = np.array([3,8,10])
lambd = np.array([1e-6,1e-2,1.0])
plt.figure(1,figsize=(40, 40), dpi=80)
for i in range (M.shape[0]):
    for j in range (lambd.shape[0]):
        theta = weights(X_A, Y_A, M, lambd)
        plt.subplot(M.shape[0], lambd.shape[0], M.shape[0]*i+j+1)
        plt.plot(X,Y,'o', X, predict(X, Y, M[i], lambd[j]), 'r-')
        xlabel = 'x, M='+str(M[i])+ ', Lambda=' +str(lambd[j])
        plt.xlabel(xlabel)
        plt.ylabel('y')

plt.show()
# Out:
# [ 1.9379859  -0.20832548  1.4248537  -1.18822757 -0.53222173 -2.05946346
#  -1.84004978  2.2035523   0.20423674 -0.22615928  2.72338905  3.02392976
#   1.99800886]
