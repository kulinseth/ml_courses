# %% [markdown]
# ## Linear Basis Function Regression
#
# The closed form solution for the maximum likelihood weight vector is given by:
#
# $$ w_{ML} = (\phi^T\phi)^{-1}\phi^{T}t $$
#
# The data is generated using :
#
# $$ y(x) = cos(\pi x) + 1.5cos(2\pi x)$$
# and hence:
# $$t = y(x,w) + \epsilon$$
#
# where is $\epsilon$ is added noise. Assuming we don't know the real basis for these points and want to try polynomial fitting to the provided dataset. The polynomial basis is given by:
#
# $$ \phi_0(x) = 1, \phi_1(x) = x ..., \phi_M(x) = x^M$$
#
# The procedure to compute the MLE estimate is:
# 1. The Likelihood function is given by
# $$ E_D(w) = ... $$
# The derivative of which leads to the closed form solution above. To evaluate the $w_ML$ gradient descent methods are used. Using the batch gradient descent method which iterates over the entire dataset
# $$w^{\tau +1} = w_{\tau} - \eta \nabla_w E_D(w)$$
#
# where $\eta$ is the learning rate.

# %%
# %matplotlib inline
import numpy as np
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pylab as pl

def getData():
    # load the fitting data and (optionally) plot out for examination
    # return the X and Y as a tuple

    data = pl.loadtxt('curvefittingp2.txt')

    X = data[0,:]
    Y = data[1,:]
    return (X,Y)

def cos_fn(X):
    Y = np.cos(np.pi*X) + np.cos(2*np.pi*X)
    return Y

def polynomial_basis(x, M):
    poly = np.arange(M+1)
    X = np.power(np.array([x]).T, poly)
    return X

# These weights are calculated using the closed form
def weights(X, Y, M, lambd):
    theta = np.dot(np.linalg.inv(lambd*np.identity(M+1) + (np.dot(X.T, X))), np.dot(X.T, Y))
    return theta
    
def predict(x, Y, M, lambd=0.0):
    X = polynomial_basis(x, M)
    theta = weights(X, Y, M, lambd)
    Y_hat = np.dot(X, theta)
    return Y_hat


if __name__ == '__main__':
    X, Y = getData()
    print X.shape
    print Y.shape
    #X = np.linspace(0.0, 1.0, 200)
    Y_cos = cos_fn(X)
    plt.figure(1,figsize=(20, 4), dpi=80)
    plt.subplot(1,4,1)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 0), 'r-')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.subplot(1,4,2)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 1), 'r-')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.subplot(1,4,3)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 3), 'r-')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.subplot(1,4,4)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 10), 'r-')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
# Out:
# (11,)
# (11,)

# %% [markdown]
# ## 3.1 Ridge Regression

# %%
    # TODO: convert this to a grid of varying Lambda and M values 4x4 grid should be good
    plt.figure(1,figsize=(20, 8), dpi=80)
    plt.subplot(2,4,1)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 10, 1e-8), 'r-')
    plt.xlabel('x, M=10, Lambda=1e-8')
    plt.ylabel('y')
    plt.subplot(2,4,2)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 10, 1e-6), 'r-')
    plt.xlabel('x, M=10, Lambda=1e-6')
    plt.ylabel('y')
    plt.subplot(2,4,3)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 10, 1e-4), 'r-')
    plt.xlabel('x, M=10, Lambda=1e-4')
    plt.ylabel('y')
    plt.subplot(2,4,4)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 10, 1e-2), 'r-')
    plt.xlabel('x, M=10, Lambda=1e-2')
    plt.ylabel('y')
    plt.subplot(2,4,5)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 6, 1e-8), 'r-')
    plt.xlabel('x, M=6, Lambda=1e-8')
    plt.ylabel('y')
    plt.subplot(2,4,6)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 6, 1e-6), 'r-')
    plt.xlabel('x, M=6, Lambda=1e-6')
    plt.ylabel('y')
    plt.subplot(2,4,7)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 6, 1e-4), 'r-')
    plt.xlabel('x, M=6, Lambda=1e-4')
    plt.ylabel('y')
    plt.subplot(2,4,8)
    plt.plot(X,Y,'o', X, Y_cos, 'y-', X, predict(X, Y, 6, 1e-2), 'r-')
    plt.xlabel('x, M=6, Lambda=1e-2')
    plt.ylabel('y')
    plt.show()

# %%
def sum_of_squares(x, Y, M):
    loss = predict(x,Y,M) - Y
    J_theta = np.sum(loss**2)/2.0
    return J_theta

def sum_of_squares_grad(x, Y, M):
    loss = predict(x,Y,M) - Y
    X = polynomial_basis(x, M)
    grad = np.dot(X.T, loss)
    return grad

def approx_gradient_method(func, x, delta):
    # This is the alternate method
    #grad = (func(x+dv) - func(x-dv))/(2.0*delta)
    dv = np.eye(x.shape[0], dtype=float)
    dv = np.multiply(dv, delta)
    grad = np.empty(x.shape[0])
    for i in range(x.shape[0]):
        grad[i] = (func(x+dv[i]) - func(x-dv[i]))/(2.0*delta)
    return grad

    
J = sum_of_squares(X, Y, 10)
print J
grad_closed_ls = sum_of_squares_grad(X, Y, 10)
print grad_closed_ls
grad_approx_ls = approx_gradient_method(sum_of_squares_func, init_ls, 1e-6)
#print grad_approx_ls
# Out:
# 0.000270669044484
# [-0.01743229 -0.01878738 -0.01209671 -0.00855298 -0.00657429 -0.00539472
#  -0.00464958 -0.00415545 -0.00381425 -0.00357049 -0.00339123]
