# %%
import numpy as np
import pandas as pd
from scipy import misc
from matplotlib import pylab as plt
import matplotlib.cm as cm
# %matplotlib inline

im = misc.imread('Mona_Lisa,_by_Leonardo_da_Vinci,_from_C2RMF_retouched.jpg', flatten=1)
plt.imshow(im, cmap=cm.Greys_r)
plt.show()
print im.shape
# Out:
# (900, 604)

# %%
im_1d = np.reshape(im, (900*604, 1))
idx_5k = np.random.randint(1, 900*604, 5000)
im_5k = np.array([im_1d[i] for i in idx_5k])
print im_5k.shape
# Out:
# (5000, 1)

# %%
idx_5k_x = idx_5k/604
idx_5k_y = idx_5k%604
print idx_5k_x[0], idx_5k_y[0]
# Out:
# 452 219
